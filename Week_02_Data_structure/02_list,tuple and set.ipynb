# %%
l=[1,4.35,"suru",True,5+8j]

# %%
l[4].real
# Out:
# 5.0

# %%
l[4].imag
# Out:
# 8.0

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[4]
# Out:
# (5+8j)

# %%
l[2]
# Out:
# 'suru'

# %%
l[970]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 l[970]
#
# IndexError: list index out of range

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j)]

# %%
l[0:4]
# Out:
# [1, 4.35, 'suru', True]

# %%
l[-1]
# Out:
# (5+8j)

# %%
l[-1:-9]
# Out:
# []

# %%
l[::-1]
# Out:
# [(5+8j), True, 'suru', 4.35, 1]

# %%
l[::2]
# Out:
# [1, 'suru', (5+8j)]

# %%
l[::3]
# Out:
# [1, True]

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j)]

# %%
s="pwakills"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
l1=list(s)

# %%
l1
# Out:
# ['p', 'w', 'a', 'k', 'i', 'l', 'l', 's']

# %%
l1+l
# Out:
# ['p', 'w', 'a', 'k', 'i', 'l', 'l', 's', 1, 4.35, 'suru', True, (5+8j)]

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j)]

# %%
type(l[2])
# Out:
# str

# %%
l[2][0:2]
# Out:
# 'su'

# %%
str(l[3])[0:2]
# Out:
# 'Tr'

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j)]

# %%
l+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 l+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1=[3,4,6]

# %%
l+l1
# Out:
# [1, 4.35, 'suru', True, (5+8j), 3, 4, 6]

# %%
l1*4
# Out:
# [3, 4, 6, 3, 4, 6, 3, 4, 6, 3, 4, 6]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j)]

# %%
l.append(5)

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j), 5]

# %%
l.append(s)

# %%
s
# Out:
# 'pwakills'

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j), 5, 'pwakills']

# %%
l1
# Out:
# [3, 4, 6]

# %%
l.append(l1)

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j), 5, 'pwakills', [3, 4, 6]]

# %%
l[-2][2]
# Out:
# 'a'

# %%
l
# Out:
# [1, 4.35, 'suru', True, (5+8j), 5, 'pwakills', [3, 4, 6]]

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("darshna")

# %%
l
# Out:
# [1,
#  4.35,
#  'suru',
#  True,
#  (5+8j),
#  5,
#  'pwakills',
#  [3, 4, 6],
#  'd',
#  'a',
#  'r',
#  's',
#  'h',
#  'n',
#  'a']

# %%
l.extend([8,4,"SUDARSH",8.5])

# %%
l
# Out:
# [1,
#  4.35,
#  'suru',
#  True,
#  (5+8j),
#  5,
#  'pwakills',
#  [3, 4, 6],
#  'd',
#  'a',
#  'r',
#  's',
#  'h',
#  'n',
#  'a',
#  8,
#  4,
#  'SUDARSH',
#  8.5]

# %%
l
# Out:
# [1,
#  4.35,
#  'suru',
#  True,
#  (5+8j),
#  5,
#  'pwakills',
#  [3, 4, 6],
#  'd',
#  'a',
#  'r',
#  's',
#  'h',
#  'n',
#  'a',
#  8,
#  4,
#  'SUDARSH',
#  8.5]

# %%
l1.insert(1,"suresh")

# %%
l
# Out:
# [1,
#  4.35,
#  'suru',
#  True,
#  (5+8j),
#  5,
#  'pwakills',
#  [3, 'suresh', 4, 6],
#  'd',
#  'a',
#  'r',
#  's',
#  'h',
#  'n',
#  'a',
#  8,
#  4,
#  'SUDARSH',
#  8.5]

# %%
l1
# Out:
# [3, 'suresh', 4, 6]

# %%
l1.insert(2,[6,73,89,"darshna"])

# %%
l1.insert(-1,84)

# %%
l1
# Out:
# [3, 'suresh', [6, 73, 89, 'darshna'], 4, 84, 6]

# %%
l1.insert(0,90)

# %%
l1
# Out:
# [90, 3, 'suresh', [6, 73, 89, 'darshna'], 4, 84, 6]

# %%
l1.pop()
# Out:
# 6

# %%
l1
# Out:
# [90, 3, 'suresh', [6, 73, 89, 'darshna'], 4, 84]

# %%
l1.pop()
# Out:
# 84

# %%
l1
# Out:
# [90, 3, 'suresh', [6, 73, 89, 'darshna'], 4]

# %%
l1.pop(3)
# Out:
# [6, 73, 89, 'darshna']

# %%
l1
# Out:
# [90, 3, 'suresh', 4]

# %%
l1.remove(3)

# %%
l1
# Out:
# [90, 'suresh', 4]

# %%
l1.remove("suresh")

# %%
l1
# Out:
# [90, 4]

# %%
l1.remove(7866)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 l1.remove(7866)
#
# ValueError: list.remove(x): x not in list

# %%
l1
# Out:
# [90, 4]

# %%
l1.insert(2,[8,8.87,"harsh"])

# %%
l1
# Out:
# [90, 4, [8, 8.87, 'harsh']]

# %%
l1[2].remove(8.87)

# %%
l1
# Out:
# [90, 4, [8, 'harsh']]

# %%
l1
# Out:
# [90, 4, [8, 'harsh']]

# %%
l1.append(67)

# %%
l1
# Out:
# [90, 4, [8, 'harsh'], 67]

# %%
l1.append(8)

# %%
l1
# Out:
# [90, 4, [8, 'harsh'], 67, 8]

# %%
l1.remove(8)

# %%
l1
# Out:
# [90, 4, [8, 'harsh'], 67]

# %%
l1=l1[::-1]

# %%
l1
# Out:
# [67, [8, 'harsh'], 4, 90]

# %%
l1.reverse()

# %%
l1
# Out:
# [90, 4, [8, 'harsh'], 67]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l2=[4,5,3,6,8,3,7,57.6]

# %%
l2
# Out:
# [4, 5, 3, 6, 8, 3, 7, 57.6]

# %%
l2.sort()

# %%
l2
# Out:
# [3, 3, 4, 5, 6, 7, 8, 57.6]

# %%
l3=[74,"suresh",74,94.39,"jugnuu"]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[265], line 1
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l4=["suru","jugnu","pagal","motii"]

# %%
l4.sort(reverse=True)

# %%
l4
# Out:
# ['suru', 'pagal', 'motii', 'jugnu']

# %%
l4
# Out:
# ['suru', 'pagal', 'motii', 'jugnu']

# %%
l4.index("pagal")
# Out:
# 1

# %%
l4.count("motii")
# Out:
# 1

# %%
s="suru"

# %%
l5=[3,4,3,6,8,9]

# %%
s[0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[278], line 1
# ----> 1 s[0]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0]=60

# %%
l5
# Out:
# [60, 4, 3, 6, 8, 9]

# %%
s
# Out:
# 'suru'

# %%
s.replace('s','a')
# Out:
# 'auru'

# %%
s
# Out:
# 'suru'

# %%
#Tuple

# %%
t=(2,4,2,54,"suru",74.83,False,63+84j,[4,84,"jugnuu"])

# %%
t
# Out:
# (2, 4, 2, 54, 'suru', 74.83, False, (63+84j), [4, 84, 'jugnuu'])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[7]
# Out:
# (63+84j)

# %%
t[-1]
# Out:
# [4, 84, 'jugnuu']

# %%
t[::-1]
# Out:
# ([4, 84, 'jugnuu'], (63+84j), False, 74.83, 'suru', 54, 2, 4, 2)

# %%
l4
# Out:
# ['suru', 'pagal', 'motii', 'jugnu']

# %%
l4[0]=6344

# %%
l4
# Out:
# [6344, 'pagal', 'motii', 'jugnu']

# %%
t
# Out:
# (2, 4, 2, 54, 'suru', 74.83, False, (63+84j), [4, 84, 'jugnuu'])

# %%
t[0]="suru"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[298], line 1
# ----> 1 t[0]="suru"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[::-1]
# Out:
# ([4, 84, 'jugnuu'], (63+84j), False, 74.83, 'suru', 54, 2, 4, 2)

# %%
t.count(50)
# Out:
# 0

# %%
t.index(False)
# Out:
# 6

# %%
t
# Out:
# (2, 4, 2, 54, 'suru', 74.83, False, (63+84j), [4, 84, 'jugnuu'])

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s2={34,3,636,86.83,"suresh",74+84j,(7,35,"jugnu")}

# %%
type(s2)
# Out:
# set

# %%
s2
# Out:
# {(7, 35, 'jugnu'), (74+84j), 3, 34, 636, 86.83, 'suresh'}

# %%
s3={5642,8976,93.973,"suru",74+7864j,(34,675,7)}

# %%
s3
# Out:
# {(34, 675, 7), (74+7864j), 5642, 8976, 93.973, 'suru'}

# %%
s4={2,3,4,5,6,7,87,8,9,9,6,3,3465,67,36,3,2,16,5,'suru',"suru","Jugnu","jugnu"}

# %%
s4
# Out:
# {16, 2, 3, 3465, 36, 4, 5, 6, 67, 7, 8, 87, 9, 'Jugnu', 'jugnu', 'suru'}

# %%
l6=[2,3,4,5,6,7,87,8,9,9,6,3,3465,67,36,3,2,16,5,'suru',"suru","Jugnu","jugnu"]

# %%
l6
# Out:
# [2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  87,
#  8,
#  9,
#  9,
#  6,
#  3,
#  3465,
#  67,
#  36,
#  3,
#  2,
#  16,
#  5,
#  'suru',
#  'suru',
#  'Jugnu',
#  'jugnu']

# %%
l6=list(set(l6))

# %%
l6
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 3465, 67, 36, 'suru', 'jugnu', 16, 'Jugnu', 87]

# %%
s5={353,5764,877643,8976,374,83,937,"abc",784,9873}

# %%
s5
# Out:
# {353, 374, 5764, 784, 83, 877643, 8976, 937, 9873, 'abc'}

# %%
s5[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[331], line 1
# ----> 1 s5[0]
#
# TypeError: 'set' object is not subscriptable

# %%
type(s5)
# Out:
# set

# %%
s5[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[333], line 1
# ----> 1 s5[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s5
# Out:
# {353, 374, 5764, 784, 83, 877643, 8976, 937, 9873, 'abc'}

# %%
s5.add(6)

# %%
s5
# Out:
# {353, 374, 5764, 6, 784, 83, 877643, 8976, 937, 9873, 'abc'}

# %%
s5.remove(5764)

# %%
s5
# Out:
# {353, 374, 6, 784, 83, 877643, 8976, 937, 9873, 'abc'}

# %%
l4
# Out:
# [6344, 'pagal', 'motii', 'jugnu']

# %%
l5
# Out:
# [60, 4, 3, 6, 8, 9]

# %%
l4+"suru"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[341], line 1
# ----> 1 l4+"suru"
#
# TypeError: can only concatenate list (not "str") to list

# %%
l5
# Out:
# [60, 4, 3, 6, 8, 9]

# %%
s={1,2,3,4,43,5,4,6,3,3}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 43}

# %%
s1={34,7354,89763,863,2,3,1,34,1,23}

# %%
s1
# Out:
# {1, 2, 3, 23, 34, 863, 7354, 89763}

# %%
l=[1,23,5,45,6,4,6,56,5]

# %%
l
# Out:
# [1, 23, 5, 45, 6, 4, 6, 56, 5]

# %%
l.insert(-1,"darshna")

# %%
l
# Out:
# [1, 23, 5, 45, 6, 4, 6, 56, 'darshna', 5]

# %%
l3=["d",'a','r','s','7','9']

# %%
l3.sort()

# %%
l3
# Out:
# ['7', '9', 'a', 'd', 'r', 's']

# %%
s="jugnu"

# %%
l
# Out:
# [1, 23, 5, 45, 6, 4, 6, 56, 'darshna', 5]

# %%
l.insert(3,list(s))

# %%
l
# Out:
# [1, 23, 5, ['j', 'u', 'g', 'n', 'u'], 45, 6, 4, 6, 56, 'darshna', 5]

# %%
l=[43,654,3,56,6,[654,4,53,5]]

# %%
l4
# Out:
# [6344, 'pagal', 'motii', 'jugnu']

# %%
l4.extend(l)

# %%
l4
# Out:
# [6344, 'pagal', 'motii', 'jugnu', 43, 654, 3, 56, 6, [654, 4, 53, 5]]

# %%
l4[4:7]
# Out:
# [43, 654, 3]

# %%
l4[2:5]
# Out:
# ['motii', 'jugnu', 43]

# %%
m="pwskills"

# %%
m[::99999]
# Out:
# 'p'

# %%
l
# Out:
# [43, 654, 3, 56, 6, [654, 4, 53, 5]]

# %%
l.append(6753)

# %%
l
# Out:
# [43, 654, 3, 56, 6, [654, 4, 53, 5], 6753]

# %%
l.extend("darshna")

# %%
l
# Out:
# [43, 654, 3, 56, 6, [654, 4, 53, 5], 6753, 'd', 'a', 'r', 's', 'h', 'n', 'a']
