# %%
l=[2,3,4,5,7,3,2,4,5]
l1=[]
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [4, 9, 16, 25, 49, 9, 4, 16, 25]

# %%
l
# Out:
# [2, 3, 4, 5, 7, 3, 2, 4, 5]

# %%
[i**2 for i in l]
# Out:
# [4, 9, 16, 25, 49, 9, 4, 16, 25]

# %%
[i for i in l if i%2==0]
# Out:
# [2, 4, 2, 4]

# %%
l1=["suru","jugnu","motii","pagal"]

# %%
[i.upper() for i in l1]
# Out:
# ['SURU', 'JUGNU', 'MOTII', 'PAGAL']

# %%
l
# Out:
# [2, 3, 4, 5, 7, 3, 2, 4, 5]

# %%
list(i**2 for i in l)
# Out:
# [4, 9, 16, 25, 49, 9, 4, 16, 25]

# %%
d={"key1":1,"kay2":2,"kay3":3,"kay4":4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 1, 'kay2': 4, 'kay3': 9, 'kay4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('kay2', 2), ('kay3', 3), ('kay4', 4)])

# %%
{k:v for k ,v in d.items() if v>1}
# Out:
# {'kay2': 2, 'kay3': 3, 'kay4': 4}
