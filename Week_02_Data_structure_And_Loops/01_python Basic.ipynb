# %%
4+6
# Out:
# 10

# %%
7*7
# Out:
# 49

# %%
a=10

# %%
a
# Out:
# 10

# %%
suru=39

# %%
suru
# Out:
# 39

# %%
a+suru
# Out:
# 49

# %%
type(a)
# Out:
# int

# %%
type(suru)
# Out:
# int

# %%
b=6.84

# %%
type(b)
# Out:
# float

# %%
c=78.69736967

# %%
type(c)
# Out:
# float

# %%
d="suresh"

# %%
type(d)
# Out:
# str

# %%
e=' this is my first class'

# %%
type(e)
# Out:
# str

# %%
n=True

# %%
type(n)
# Out:
# bool

# %%
m=False

# %%
type(m)
# Out:
# bool

# %%
n+m
# Out:
# 1

# %%
True*True
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
x=3+7j

# %%
type(x)
# Out:
# complex

# %%
x.imag
# Out:
# 7.0

# %%
x.real
# Out:
# 3.0

# %%
suru=6+3.7j

# %%
suru.imag
# Out:
# 3.7

# %%
suru.real
# Out:
# 6.0

# %%
suru
# Out:
# (6+3.7j)

# %%
print("my name is suresh")
# Out:
# my name is suresh

# %%
print(suru)
# Out:
# (6+3.7j)

# %%
print(a)
# Out:
# 10

# %%
s="pwskills"

# %%
type(s)
# Out:
# str

# %%
s[1]
# Out:
# 'w'

# %%
s[6]
# Out:
# 'l'

# %%
s[0]
# Out:
# 'p'

# %%
s[3]
# Out:
# 'k'

# %%
s[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 s[8]
#
# IndexError: string index out of range

# %%
s[-1]
# Out:
# 's'

# %%
s[-8]
# Out:
# 'p'

# %%
s[-5]
# Out:
# 'k'

# %%
s[0:3]
# Out:
# 'pws'

# %%
s[0:4]
# Out:
# 'pwsk'

# %%
s[0:8:2]
# Out:
# 'psil'

# %%
s[::2]
# Out:
# 'psil'

# %%
s[::3]
# Out:
# 'pkl'

# %%
s[2::2]
# Out:
# 'sil'

# %%
s[2::0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 s[2::0]
#
# ValueError: slice step cannot be zero

# %%
s[::-1]
# Out:
# 'sllikswp'

# %%
s[-1:-9:-1]
# Out:
# 'sllikswp'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[:10]
# Out:
# 'pwskills'

# %%
s[8:0]
# Out:
# ''

# %%
s[8::-1]
# Out:
# 'sllikswp'

# %%
s[-2:-8:1]
# Out:
# ''

# %%
s[-2::-1]
# Out:
# 'llikswp'

# %%
s[::-1]
# Out:
# 'sllikswp'

# %%
s[:-8:-1]
# Out:
# 'slliksw'

# %%
s[::1]
# Out:
# 'pwskills'

# %%
s[::]
# Out:
# 'pwskills'

# %%
s[:39:]
# Out:
# 'pwskills'

# %%
s[:-32:]
# Out:
# ''

# %%
s[78]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 s[78]
#
# IndexError: string index out of range

# %%
s[:37:-1]
# Out:
# ''

# %%
s[:-8766:-1]
# Out:
# 'sllikswp'

# %%
s[-7:8]
# Out:
# 'wskills'

# %%
c=200

# %%
c
# Out:
# 200

# %%
s1="this is my str class"

# %%
len(s1)
# Out:
# 20

# %%
s1.find('s')
# Out:
# 3

# %%
s1.find('i')
# Out:
# 2

# %%
s1.find("is")
# Out:
# 2

# %%
This is a code to find characterd of sub m
s1.find("iS")
# Out:
# -1

# %%
s1.count("st")
# Out:
# 1

# %%
s1.count('z')
# Out:
# 0

# %%
s1.count('s')
# Out:
# 5

# %%
s1.upper()
# Out:
# 'THIS IS MY STR CLASS'

# %%
s2='THIS IS MY STR CLASS'

# %%
s2
# Out:
# 'THIS IS MY STR CLASS'

# %%
s2.lower()
# Out:
# 'this is my str class'

# %%
s1
# Out:
# 'this is my str class'

# %%
s2.title()
# Out:
# 'This Is My Str Class'

# %%
s1.capitalize()
# Out:
# 'This is my str class'

# %%
s
# Out:
# 'pwskills'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+'1'
# Out:
# 'pwskills1'

# %%
s+" suresh"
# Out:
# 'pwskills suresh'

# %%
s+str(1)
# Out:
# 'pwskills1'

# %%
s*3
# Out:
# 'pwskillspwskillspwskills'

# %%
"suresh"/3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 "suresh"/3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
'don't copy and paste in my class'
# Out:
#   Cell In[131], line 1
#     'don't copy and paste in my class'
#                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"don't copy and paste in my class"
# Out:
# "don't copy and paste in my class"

# %%
'don"t copy and paste in my class'
# Out:
# 'don"t copy and paste in my class'

# %%
#This is my first class for programming

# %%
s3 = """i have leant variable declaration, data type ,str,int.bool,complex
i have seen exp of str slicibg and indexing
i have gone though some of the string inbuilt fun
apart from that i am trying to practice in my sys"""

# %%
s3
# Out:
# 'i have leant variable declaration, data type ,str,int.bool,complex\ni have seen exp of str slicibg and indexing\ni have gone though some of the string inbuilt fun\napart from that i am trying to practice in my sys'
