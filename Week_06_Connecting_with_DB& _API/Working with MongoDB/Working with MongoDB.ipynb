# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://pwskillss:pwskills@cluster0.cemddwr.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pymongo
clint =pymongo.MongoClient( "mongodb+srv://pwskillss:pwskills@cluster0.cemddwr.mongodb.net/?appName=Cluster0")
db=client.test

# %%
clint =pymongo.MongoClient( "mongodb+srv://pwskillss:pwskills@cluster0.cemddwr.mongodb.net/?appName=Cluster0")

# %%
db=client['pwskills']

# %%
data={
    "name":"suresh",
    "class":"data science mastre",
    "time":"flexi"
}

# %%
coll_pwakills=db["my_record"]

# %%
coll_pwakills.insert_one(data)
# Out:
# InsertOneResult(ObjectId('69a97a4e9d8aa433e4cea20f'), acknowledged=True)

# %%
data1={"mail_id":"suru@gmail.com",
      "phone":986587,
      "add":"padru"}

# %%
coll_pwakills.insert_one(data1)
# Out:
# InsertOneResult(ObjectId('69a97ae59d8aa433e4cea210'), acknowledged=True)

# %%
data2 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_pwakills.insert_many(data2)
# Out:
# InsertManyResult([ObjectId('69a97bcf9d8aa433e4cea211'), ObjectId('69a97bcf9d8aa433e4cea212'), ObjectId('69a97bcf9d8aa433e4cea213'), ObjectId('69a97bcf9d8aa433e4cea214'), ObjectId('69a97bcf9d8aa433e4cea215'), ObjectId('69a97bcf9d8aa433e4cea216'), ObjectId('69a97bcf9d8aa433e4cea217'), ObjectId('69a97bcf9d8aa433e4cea218'), ObjectId('69a97bcf9d8aa433e4cea219'), ObjectId('69a97bcf9d8aa433e4cea21a'), ObjectId('69a97bcf9d8aa433e4cea21b'), ObjectId('69a97bcf9d8aa433e4cea21c')], acknowledged=True)

# %%
data3 = {
 "name": "notebook",
 "qty": 50,
 "rating": [ { "score": 8 }, { "score": 9 } ],
 "size": { "height": 11, "width": 8.5, "unit": "in" },
 "status": "A",
 "tags": [ "college-ruled", "perforated"]
}

# %%
coll_pwakills.insert_one(data3)
# Out:
# InsertOneResult(ObjectId('69a97c4c9d8aa433e4cea21d'), acknowledged=True)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
coll_pwakills.insert_many(list_of_records)
# Out:
# InsertManyResult([ObjectId('69a97f879d8aa433e4cea221'), ObjectId('69a97f879d8aa433e4cea222'), ObjectId('69a97f879d8aa433e4cea223')], acknowledged=True)

# %%
coll_pwakills.find_one()
# Out:
# {'_id': ObjectId('69a97a4e9d8aa433e4cea20f'),
#  'name': 'suresh',
#  'class': 'data science mastre',
#  'time': 'flexi'}

# %%
for i in coll_pwakills.find():
    print(i)
# Out:
# {'_id': ObjectId('69a97a4e9d8aa433e4cea20f'), 'name': 'suresh', 'class': 'data science mastre', 'time': 'flexi'}
# {'_id': ObjectId('69a97ae59d8aa433e4cea210'), 'mail_id': 'suru@gmail.com', 'phone': 986587, 'add': 'padru'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea211'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea212'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea213'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea214'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea215'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea216'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea217'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea218'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# ...

# %%
for i in coll_pwakills.find({'name': 'suresh'}):
    print(i)
# Out:
# {'_id': ObjectId('69a97a4e9d8aa433e4cea20f'), 'name': 'suresh', 'class': 'data science mastre', 'time': 'flexi'}

# %%
for i in coll_pwakills.find({'companyName': 'iNeuron'}):
    print(i)
# Out:
# {'_id': ObjectId('69a97f879d8aa433e4cea221'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('69a97f879d8aa433e4cea222'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('69a97f879d8aa433e4cea223'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
random_data = [
    {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'},
]

# %%
coll_pwakills.insert_many(random_data)
# Out:
# InsertManyResult(['3', '4', '5'], acknowledged=True)

# %%
for i in coll_pwakills.find():
    print(i)
# Out:
# {'_id': ObjectId('69a97a4e9d8aa433e4cea20f'), 'name': 'suresh', 'class': 'data science mastre', 'time': 'flexi'}
# {'_id': ObjectId('69a97ae59d8aa433e4cea210'), 'mail_id': 'suru@gmail.com', 'phone': 986587, 'add': 'padru'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea211'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea212'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea213'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea214'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea215'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea216'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea217'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea218'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# ...

# %%
for i in coll_pwakills.find({"_id":{"$gte":'4'}}):
    print(i)
# Out:
# {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'}

# %%
coll_pwakills.update_many({'companyName': 'iNeuron'},{"$set":{'companyName': 'pwskills'}})
# Out:
# UpdateResult({'n': 6, 'electionId': ObjectId('7fffffff0000000000000144'), 'opTime': {'ts': Timestamp(1772715933, 12), 't': 324}, 'nModified': 6, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1772715933, 12), 'signature': {'hash': b'E\xdaT\xa8\xc6\xe4X\x18\xd5\xdaAD\xf7\xad\x9f\x81\xdd\x1f\x96~', 'keyId': 7581614744939790338}}, 'operationTime': Timestamp(1772715933, 12), 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll_pwakills.find():
    print(i)
# Out:
# {'_id': ObjectId('69a97a4e9d8aa433e4cea20f'), 'name': 'suresh', 'class': 'data science mastre', 'time': 'flexi'}
# {'_id': ObjectId('69a97ae59d8aa433e4cea210'), 'mail_id': 'suru@gmail.com', 'phone': 986587, 'add': 'padru'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea211'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea212'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea213'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea214'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea215'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea216'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea217'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('69a97bcf9d8aa433e4cea218'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# ...
