# %%
f=open("test.txt",'w')

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\suresh\\PW_INTERSHIP\\Week_05_'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6A7F-181C
#
#  Directory of C:\Users\Admin\Desktop\suresh\PW_INTERSHIP\Week_05_
#
# 19-02-2026  17:09    <DIR>          .
# 19-02-2026  16:40    <DIR>          ..
# 19-02-2026  16:58    <DIR>          .ipynb_checkpoints
# 19-02-2026  17:09                 0 test.txt
# 19-02-2026  17:09            11,038 working with files hindi.ipynb
#                2 File(s)         11,038 bytes
#                3 Dir(s)  329,665,781,760 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\suresh\\PW_INTERSHIP\\Week_05_'

# %%
f.write("this is my first file to write")
# Out:
# 30

# %%
f.close()

# %%
f=open("test.txt",'w')

# %%
f.write("this is my file")
# Out:
# 15

# %%
f.close()

# %%
f=open("test.txt",'a')

# %%
f.write("""Developer: An organism that turns coffee into code,
Traveling down a logical, syntax-filled road.
From midnight errors to morning light,
We fix the logic with all our might.""")
# Out:
# 173

# %%
f.close()

# %%
data=open("test.txt",'r')

# %%
data.read()
# Out:
# 'this is my fileDeveloper: An organism that turns coffee into code,\nTraveling down a logical, syntax-filled road.\nFrom midnight errors to morning light,\nWe fix the logic with all our might.'

# %%
data.readline()
# Out:
# ''

# %%
data.seek(0)
# Out:
# 0

# %%
data.seek(10)
# Out:
# 10

# %%
data.readline()
# Out:
# ' fileDeveloper: An organism that turns coffee into code,\n'

# %%
data.seek(100)
# Out:
# 100

# %%
data.readline()
# Out:
# '-filled road.\n'

# %%
data1=open("test.txt",'r')

# %%
for i in data1:
    print(i)
# Out:
# this is my fileDeveloper: An organism that turns coffee into code,
#
# Traveling down a logical, syntax-filled road.
#
# From midnight errors to morning light,
#
# We fix the logic with all our might.

# %%
data1.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data1.close()
#
# NameError: name 'data1' is not defined

# %%
import os

# %%
os.path.getsize("test.txt")
# Out:
# 191

# %%
os.remove("test2.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 os.remove("test2.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'test2.txt'

# %%
f=open("test3.txt",'w', encoding="utf-8")

# %%
f.write("""Your love is like a semicolon,
Without it, I am just an error.
I’ll debug my life for you,
To make our love, a final winner""")
# Out:
# 123

# %%
f.close()

# %%
os.rename("test3.txt","new.txt")

# %%
import shutil

# %%
shutil.copy("new.txt","copy_new.txt")
# Out:
# 'copy_new.txt'

# %%
with open("new.txt","r") as f:
    print(f.read())
# Out:
# Your love is like a semicolon,
# Without it, I am just an error.
# Iâ€™ll debug my life for you,
# To make our love, a final winner
