# %%
a=10

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
f =open("Test.txt","r")
print("This is my print")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f =open("Test.txt","r")
#       2 print("This is my print")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Test.txt'

# %%
try:
    f =open("Test.txt","r")
except Exception as e:
    print("This id my except block",e)
a=4+4
a
# Out:
# This id my except block [Errno 2] No such file or directory: 'Test.txt'
# 8

# %%
try:
    f =open("Test.txt","w")
    f.write("Write into my file")
except Exception as e:
    print("This id my except block",e)
else:
    f.close()
    print("This will be executed once your try will executed without erroe")
# Out:
# This will be executed once your try will executed without erroe

# %%
try:
    f =open("Test1.txt","r")
    f.write("Write into my file")
except Exception as e:
    print("This id my except block",e)
else:
    f.close()
    print("This will be executed once your try will executed without erroe")
# Out:
# This id my except block [Errno 2] No such file or directory: 'Test1.txt'

# %%
try:
    f=open("test2.txt","w")
    f.write("Write something")
else:
    f.close()
finally:
    print("Finally will be executed itself in any situation")
# Out:
# Finally will be executed itself in any situation

# %%
try:
    f=open("test3.txt","r")
    f.write("Write something")
finally:
    print("Finally will be executed itself in any situation")
# Out:
# Finally will be executed itself in any situation
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 try:
# ----> 2     f=open("test3.txt","r")
#       3     f.write("Write something")
#       4 finally:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test3.txt'
