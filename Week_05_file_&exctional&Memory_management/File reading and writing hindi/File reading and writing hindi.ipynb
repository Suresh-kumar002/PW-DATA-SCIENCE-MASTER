# %%
data={
    "name":"suresh",
    "mail_id":"suresh@gmail.com",
    "phone":8441028976,
    "subject":["data science","big data","data analytics"]
}

# %%
import json

# %%
with open("data.json","w") as f:
    json.dump(data,f)

# %%
with open("data.json","r") as f:
    data1=json.load(f)

# %%
data1
# Out:
# {'name': 'suresh',
#  'mail_id': 'suresh@gmail.com',
#  'phone': 8441028976,
#  'subject': ['data science', 'big data', 'data analytics']}

# %%
data1['subject']
# Out:
# ['data science', 'big data', 'data analytics']

# %%
data1['subject'][1]
# Out:
# 'big data'

# %%
import csv

# %%
data=[["name","email","phone"],
      ["motii","moti!@gmail.com",7896349698],
      ["suru","sursh@gmail.com",98768096]
     
]

# %%
with open("data.csv","w") as f:
    writer=csv.writer(f)

    for i in data:
        writer.writerow(i)

# %%
with open("data.csv","r") as f:
    read_data=csv.reader(f)

    for i in read_data:
        print(i)
# Out:
# ['name', 'email', 'phone']
# []
# ['motii', 'moti!@gmail.com', '7896349698']
# []
# ['suru', 'sursh@gmail.com', '98768096']
# []

# %%
with open("test.bin","wb") as f:
    f.write(b"\x01\x02\x03\x87")

# %%
with open("test.bin","rb") as f:
    print(f.read())
# Out:
# b'\x01\x02\x03\x87'

# %%
import os

# %%
os.remove("test1.bin")
