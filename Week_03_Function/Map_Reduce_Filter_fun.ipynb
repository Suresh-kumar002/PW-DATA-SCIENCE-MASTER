# %%
l=[2,3,5,6,4,56]

# %%
def test(l):
    l1=[]
    for i in l:
        l1.append(i**2)
    return l1

# %%
test(l)
# Out:
# [4, 9, 25, 36, 16, 3136]

# %%
def sq(x):
    return x**2

# %%
list(map(sq,l))
# Out:
# [4, 9, 25, 36, 16, 3136]

# %%
list(map(lambda x:x**2,l))
# Out:
# [4, 9, 25, 36, 16, 3136]

# %%
l1=[3,4,654,645,5]
l2=[34,56,876,43,32]

list(map(lambda x,y:x+y,l1,l2))
# Out:
# [37, 60, 1530, 688, 37]

# %%
def add(x,y):
    return x+y

# %%
list(map(add,l1,l2))
# Out:
# [37, 60, 1530, 688, 37]

# %%
s="jugnumotii"

list(map(lambda s:s.upper(),s))
# Out:
# ['J', 'U', 'G', 'N', 'U', 'M', 'O', 'T', 'I', 'I']

# %%
from functools import reduce

# %%
l=[1,2,3,4,5,67,5,43,6]

# %%
reduce(lambda x,y:x+y,l)
# Out:
# 136

# %%
reduce(lambda x,y,z:x+y+z,[])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 reduce(lambda x,y,z:x+y+z,[])
#
# TypeError: reduce() of empty iterable with no initial value

# %%
reduce(lambda x,y,z:x+y+z,[1])
# Out:
# 1

# %%
reduce(lambda x,y:x+y,l)
# Out:
# 136

# %%
l
# Out:
# [1, 2, 3, 4, 5, 67, 5, 43, 6]

# %%
reduce(lambda x,y:x if x>y else y,l)
# Out:
# 67

# %%
l
# Out:
# [1, 2, 3, 4, 5, 67, 5, 43, 6]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 67, 5, 43, 6]

# %%
list(filter(lambda x:x%2==0,l))
# Out:
# [2, 4, 6]

# %%
list(filter(lambda x:x%2!=0,l))
# Out:
# [1, 3, 5, 67, 5, 43]

# %%
l1=[2,3,4,5,-5,3,-3,-34]

# %%
list(filter(lambda x:x<0 ,l1))
# Out:
# [-5, -3, -34]

# %%
l2=["suresh","jugnu","motii","sanju","divya","harshita","nilam","Darshna"]

# %%
list(filter(lambda x:len(x)>6, l2))
# Out:
# ['harshita', 'Darshna']
