# %%
n=int(input("Enter the n :"))
p=int(input("Enter the p: "))
# Out:
# Enter the n : 2
# Enter the p:  3

# %%
def test(n,p):
    return n**p

# %%
test(n,p)
# Out:
# 8

# %%
a=lambda n,p: n**p

# %%
a(n,p)
# Out:
# 8

# %%
add=lambda x,y:x+y

# %%
add(n,p)
# Out:
# 5

# %%
c_to_f=lambda c:(9/5)*c+32

# %%
c_to_f(45)
# Out:
# 113.0

# %%
finding_max=lambda x,y:x if x>y else y

# %%
finding_max(34,12)
# Out:
# 34

# %%
s="motiijugnu"

# %%
fin_len=lambda s: len(s)

# %%
fin_len(s)
# Out:
# 10
